# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelrdealmeida/fundamentos_quinta/blob/main/fundamento01_quinta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de bibliotecas

# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

caminho_padrao = "/content/gdrive/MyDrive" # comum a todos os usuários
caminho_especifico = "/ColabNotebooks/bd/notas_mre_quinta.json" # caminho especifido de cada usuário
caminho_completo = caminho_padrao + caminho_especifico
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_json(caminho_completo, orient="columns")
df = pd.json_normalize(df["_default"])
df
# Out:
#                                                  titulo  \
# 0              Concurso Itamaraty de Arte Contemporânea
# 1     ASPA – III Reunião de Cúpula de Chefes de Esta...
# 2     Visita do Ministro Antonio de Aguiar Patriota ...
# 3                             Acidente aéreo na Namíbia
# 4     Eleição do candidato brasileiro à Secretaria-E...
# ...                                                 ...
# 1289                  IX Conferência Ministerial da OMC
# 1290  Calendário de eventos entre 9 e 15 de dezembro...
# 1291  Comunicado Conjunto dos Estados Partes do MERC...
# 1292  Exéquias do ex-Presidente Nelson Mandela - Cob...
# 1293  Círio de Nazaré torna-se Patrimônio Cultural I...
#
#                                                    link        data horario  \
# 0     https://www.gov.br/mre/pt-br/canais_atendiment...  18/01/2011   09h59
# 1     https://www.gov.br/mre/pt-br/canais_atendiment...  07/01/2011   12h15
# ...

# %%
df.shape
# Out:
# (1294, 7)

# %%
df.columns
# Out:
# Index(['titulo', 'link', 'data', 'horario', 'data_atualizada',
#        'horario_atualizado', 'paragrafos'],
#       dtype='object')

# %%
df_customizado = df[["data", "horario","titulo"]]
df_customizado
# Out:
#             data horario                                             titulo
# 0     18/01/2011   09h59           Concurso Itamaraty de Arte Contemporânea
# 1     07/01/2011   12h15  ASPA – III Reunião de Cúpula de Chefes de Esta...
# 2     04/03/2011   18h19  Visita do Ministro Antonio de Aguiar Patriota ...
# 3     30/11/2013   14h34                          Acidente aéreo na Namíbia
# 4     29/11/2013   19h03  Eleição do candidato brasileiro à Secretaria-E...
# ...          ...     ...                                                ...
# 1289  07/12/2013   09h31                  IX Conferência Ministerial da OMC
# 1290  06/12/2013   18h58  Calendário de eventos entre 9 e 15 de dezembro...
# 1291  06/12/2013   18h20  Comunicado Conjunto dos Estados Partes do MERC...
# 1292  06/12/2013   12h26  Exéquias do ex-Presidente Nelson Mandela - Cob...
# 1293  04/12/2013   18h06  Círio de Nazaré torna-se Patrimônio Cultural I...
#
# [1294 rows x 3 columns]

# %%
df.head(3)
# Out:
#                                               titulo  \
# 0           Concurso Itamaraty de Arte Contemporânea
# 1  ASPA – III Reunião de Cúpula de Chefes de Esta...
# 2  Visita do Ministro Antonio de Aguiar Patriota ...
#
#                                                 link        data horario  \
# 0  https://www.gov.br/mre/pt-br/canais_atendiment...  18/01/2011   09h59
# 1  https://www.gov.br/mre/pt-br/canais_atendiment...  07/01/2011   12h15
# 2  https://www.gov.br/mre/pt-br/canais_atendiment...  04/03/2011   18h19
#
#   data_atualizada horario_atualizado  \
# 0      31/10/2022              17h23
# 1      31/10/2022              17h23
# 2      31/10/2022              17h25
#
#                                           paragrafos
# 0  [O Ministério das Relações Exteriores informa ...
# 1  [Os jornalistas interessados em fazer a cobert...
# 2  [, O Ministro Antonio de Aguiar Patriota reali...

# %%
df_customizado.dtypes
# Out:
# data       object
# horario    object
# titulo     object
# dtype: object

# %%
df_customizado["data_formatada"] = pd.to_datetime(df_customizado["data"]).dt.year
contagem_por_ano = df_customizado["data_formatada"].value_counts()
contagem_por_ano = contagem_por_ano.to_frame()
contagem_por_ano
# Out:
# <ipython-input-34-c56acab97868>:1: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#
# <ipython-input-34-c56acab97868>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       data_formatada
# 2011             375
# 2012             348
# 2013             291
# 2014             271
# 2008               3
# 2005               3
# 2010               1
# 2004               1
# 1997               1

# %%
grafico_notas_por_ano = px.bar(contagem_por_ano, y="data_formatada")
grafico_notas_por_ano
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
